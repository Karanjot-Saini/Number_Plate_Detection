# %% [markdown]
# <a href="https://colab.research.google.com/github/Karanjot-Saini/Number_Plate_Detection/blob/main/Training_for_Number_Plate_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# %pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.8/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 82.8MB/s]
#
# 2024-05-05 08:46:03.472472: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 08:46:03.472539: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 08:46:03.473934: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-05 08:46:04.547336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# ...

# %%
pip install google-colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  1346-4340-1-SM.docx
# '1 Gagandeep Singh - Family Information - IMM5406e-Completed.gdoc'
# '1 Gagandeep Singh - Family Information - IMM5406e-Completed.pdf'
#  20200713130944-puadmissionnotice2020-21.pdf
#  Classroom
# 'Colab Notebooks'
#  DJI_0055.mov
# 'Getting started.pdf'
# 'Half Girlfriend by Chetan Bhagat ( PDFDrive.com ).pdf'
# 'Indian.v2i.yolov8.zip (Unzipped Files)'
# 'Internship & Job Preparation Training - Certificate of Completion.pdf'
#  Invoice_10755145495.pdf
#  Invoice_15292762343.pdf
#  Invoice_19504408545.pdf
#  Invoice_20113893077.pdf
# 'Invoice july august.pdf'
# 'Karanjot Sing,2018927.pdf'
# 'Karanjot_Singh_2018927 (1).pdf'
# 'Karanjot_Singh_2018927 (2).pdf'
# 'Karanjot_Singh_2018927_CSE (10).pdf'
# 'Karanjot_Singh_2018927_CSE-1 (1) (1).pdf'
# 'Karanjot_Singh_2018927_CSE (1) (1).pdf'
# 'Karanjot_Singh_2018927_CSE (11).pdf'
# 'Karanjot_Singh_2018927_CSE-1 (1).pdf'
# 'Karanjot_Singh_2018927_CSE (1) (2).pdf'
# ...

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/Number_Plate.zip
# Out:
# /content/datasets
# Archive:  /content/gdrive/MyDrive/Number_Plate.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: train/
#    creating: train/images/
#  extracting: train/images/0073797c-a755-4972-b76b-8ef2b31d44ab___new_IMG_20160315_071740-jpg_jpeg.rf.58566f9b8ce5468132bb42928ec85ccf.jpg
#  extracting: train/images/00b42b2c-f193-4863-b92c-0245cbc816da___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_Nissan-Terrano-Petrol-Review-Images-Black-Front-Angle_jpg.rf.c1af5ab742b1a0c855e5264e295a5595.jpg
#  extracting: train/images/018b52e6-e9a1-42c2-8ce7-0617e8c8e021___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_sbtb02_auto1_JPG.rf.94be8f41709439d6238ab5b357e86c4e.jpg
#  extracting: train/images/07064c2c-2aa3-4419-91a4-92916de8e54c___mahindra-scorpio-old-car-500x500-jpg_jpeg.rf.6f003cff871cedc1d2ae967722d23e4e.jpg
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 144MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
